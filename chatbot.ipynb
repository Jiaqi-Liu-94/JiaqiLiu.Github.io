# %%
import numpy as np

from keras.models import Sequential

from keras.layers import Dense, Activation, Dropout

from keras.optimizers import SGD

import random

import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

import json

import pickle

intents_file = open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/intents.json').read()

intents = json.loads(intents_file)

# %%
words=[]

classes = []

documents = []

ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:

    for pattern in intent['patterns']:

     #tokenize each word

        word = nltk.word_tokenize(pattern)

        words.extend(word)        

        #add documents in the corpus

        documents.append((word, intent['tag']))

        # add to our classes list

        if intent['tag'] not in classes:

            classes.append(intent['tag'])

print(documents)
# Out:
# [(['Hi', 'there'], 'greeting'), (['How', 'are', 'you'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hey'], 'greeting'), (['Hola'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['Bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['Nice', 'chatting', 'to', 'you', ',', 'bye'], 'goodbye'), (['Till', 'next', 'time'], 'goodbye'), (['Thanks'], 'thanks'), (['Thank', 'you'], 'thanks'), (['That', "'s", 'helpful'], 'thanks'), (['Awesome', ',', 'thanks'], 'thanks'), (['Thanks', 'for', 'helping', 'me'], 'thanks'), (['How', 'you', 'could', 'help', 'me', '?'], 'options'), (['What', 'you', 'can', 'do', '?'], 'options'), (['What', 'help', 'you', 'provide', '?'], 'options'), (['How', 'you', 'can', 'be', 'helpful', '?'], 'options'), (['What', 'support', 'is', 'offered'], 'options'), (['How', 'to', 'check', 'Adverse', 'drug', 'reaction', '?'], 'adverse_drug'), (['Open', 'adverse', 'drugs', 'module'], 'adverse_drug'), (['Give', 'me', 'a', 'list', 'of', 'drugs', 'causing', 'adverse', 'behavior'], 'adverse_drug'), (['List', 'all', 'drugs', 'suitable', 'for', 'patient', 'with', 'adverse', 'reaction'], 'adverse_drug'), (['Which', 'drugs', 'dont', 'have', 'adverse', 'reaction', '?'], 'adverse_drug'), (['Open', 'blood', 'pressure', 'module'], 'blood_pressure'), (['Task', 'related', 'to', 'blood', 'pressure'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'entry'], 'blood_pressure'), (['I', 'want', 'to', 'log', 'blood', 'pressure', 'results'], 'blood_pressure'), (['Blood', 'pressure', 'data', 'management'], 'blood_pressure'), (['I', 'want', 'to', 'search', 'for', 'blood', 'pressure', 'result', 'history'], 'blood_pressure_search'), (['Blood', 'pressure', 'for', 'patient'], 'blood_pressure_search'), (['Load', 'patient', 'blood', 'pressure', 'result'], 'blood_pressure_search'), (['Show', 'blood', 'pressure', 'results', 'for', 'patient'], 'blood_pressure_search'), (['Find', 'blood', 'pressure', 'results', 'by', 'ID'], 'blood_pressure_search'), (['Find', 'me', 'a', 'pharmacy'], 'pharmacy_search'), (['Find', 'pharmacy'], 'pharmacy_search'), (['List', 'of', 'pharmacies', 'nearby'], 'pharmacy_search'), (['Locate', 'pharmacy'], 'pharmacy_search'), (['Search', 'pharmacy'], 'pharmacy_search'), (['Lookup', 'for', 'hospital'], 'hospital_search'), (['Searching', 'for', 'hospital', 'to', 'transfer', 'patient'], 'hospital_search'), (['I', 'want', 'to', 'search', 'hospital', 'data'], 'hospital_search'), (['Hospital', 'lookup', 'for', 'patient'], 'hospital_search'), (['Looking', 'up', 'hospital', 'details'], 'hospital_search')]

# %%
# lemmaztize and lower each word and remove duplicates

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_letters]

words = sorted(list(set(words)))

# sort classes

classes = sorted(list(set(classes)))

# documents = combination between patterns and intents

print (len(documents), "documents")

# classes = intents

print (len(classes), "classes", classes)

# words = all words, vocabulary

print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/words.pkl','wb'))

pickle.dump(classes,open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 87 unique lemmatized words ["'s", 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %%
# create the training data

training = []

# create empty array for the output

output_empty = [0] * len(classes)

# training set, bag of words for every sentence

for doc in documents:

    # initializing bag of words

    bag = []

    # list of tokenized words for the pattern

    word_patterns = doc[0]

    # lemmatize each word - create base word, in attempt to represent related words

    word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]

    # create the bag of words array with 1, if word is found in current pattern

    for word in words:

        bag.append(1) if word in word_patterns else bag.append(0)

        

    # output is a '0' for each tag and '1' for current tag (for each pattern)

    output_row = list(output_empty)

    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

# shuffle the features and make numpy array

random.shuffle(training)

training = np.array(training)

# create training and testing lists. X - patterns, Y - intents

train_x = list(training[:,0])

train_y = list(training[:,1])

print("Training data is created")
# Out:
# Training data is created

# %%
# deep neural networds model

model = Sequential()

model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))

model.add(Dropout(0.5))

model.add(Dense(len(train_y[0]), activation='softmax'))

# Compiling model. SGD with Nesterov accelerated gradient gives good results for this model

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])


#Training and saving the model 

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)

model.save('chatbot_model.h5', hist)

print("model is created")
# Out:
# Epoch 1/200
# 10/10 [==============================] - 0s 695us/step - loss: 2.1915 - accuracy: 0.1489
# Epoch 2/200
# 10/10 [==============================] - 0s 686us/step - loss: 2.1803 - accuracy: 0.0851
# Epoch 3/200
# 10/10 [==============================] - 0s 676us/step - loss: 2.0293 - accuracy: 0.2979
# Epoch 4/200
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9759 - accuracy: 0.3191
# Epoch 5/200
# 10/10 [==============================] - 0s 853us/step - loss: 1.9529 - accuracy: 0.3404
# Epoch 6/200
# 10/10 [==============================] - 0s 975us/step - loss: 1.7092 - accuracy: 0.5106
# Epoch 7/200
# 10/10 [==============================] - 0s 669us/step - loss: 1.5846 - accuracy: 0.5957
# Epoch 8/200
# 10/10 [==============================] - 0s 787us/step - loss: 1.5497 - accuracy: 0.4894
# Epoch 9/200
# 10/10 [==============================] - 0s 714us/step - loss: 1.3499 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 758us/step - loss: 1.2073 - accuracy: 0.6170
# Epoch 11/200
# 10/10 [==============================] - 0s 991us/step - loss: 1.1829 - accuracy: 0.6170
# Epoch 12/200
# 10/10 [==============================] - 0s 648us/step - loss: 1.0600 - accuracy: 0.7021
# Epoch 13/200
# 10/10 [==============================] - 0s 722us/step - loss: 1.0488 - accuracy: 0.6596
# Epoch 14/200
# 10/10 [==============================] - 0s 772us/step - loss: 0.7855 - accuracy: 0.7660
# Epoch 15/200
# 10/10 [==============================] - 0s 981us/step - loss: 0.8466 - accuracy: 0.7447
# Epoch 16/200
# 10/10 [==============================] - 0s 708us/step - loss: 0.7697 - accuracy: 0.7447
# Epoch 17/200
# 10/10 [==============================] - 0s 584us/step - loss: 0.6161 - accuracy: 0.8511
# Epoch 18/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.4987 - accuracy: 0.8723
# Epoch 19/200
# 10/10 [==============================] - 0s 999us/step - loss: 0.4606 - accuracy: 0.8723
# Epoch 20/200
# 10/10 [==============================] - 0s 929us/step - loss: 0.3921 - accuracy: 0.9574
# Epoch 21/200
# 10/10 [==============================] - 0s 800us/step - loss: 0.5605 - accuracy: 0.8085
# Epoch 22/200
# 10/10 [==============================] - 0s 587us/step - loss: 0.4274 - accuracy: 0.9574
# Epoch 23/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.3571 - accuracy: 0.9362
# Epoch 24/200
# 10/10 [==============================] - 0s 828us/step - loss: 0.4042 - accuracy: 0.8723
# Epoch 25/200
# 10/10 [==============================] - 0s 734us/step - loss: 0.3470 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 874us/step - loss: 0.3209 - accuracy: 0.9149
# Epoch 27/200
# 10/10 [==============================] - 0s 888us/step - loss: 0.3318 - accuracy: 0.9149
# Epoch 28/200
# 10/10 [==============================] - 0s 809us/step - loss: 0.3584 - accuracy: 0.8298
# Epoch 29/200
# 10/10 [==============================] - 0s 677us/step - loss: 0.3075 - accuracy: 0.9149
# Epoch 30/200
# 10/10 [==============================] - 0s 900us/step - loss: 0.3530 - accuracy: 0.8723
# Epoch 31/200
# 10/10 [==============================] - 0s 963us/step - loss: 0.3515 - accuracy: 0.8936
# Epoch 32/200
# 10/10 [==============================] - 0s 876us/step - loss: 0.2374 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 781us/step - loss: 0.1827 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 589us/step - loss: 0.2532 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 806us/step - loss: 0.1752 - accuracy: 1.0000
# Epoch 36/200
# 10/10 [==============================] - 0s 636us/step - loss: 0.1961 - accuracy: 0.9574
# Epoch 37/200
# 10/10 [==============================] - 0s 882us/step - loss: 0.1614 - accuracy: 0.9787
# Epoch 38/200
# 10/10 [==============================] - 0s 625us/step - loss: 0.2209 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 919us/step - loss: 0.1705 - accuracy: 0.9574
# Epoch 40/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1716 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 906us/step - loss: 0.1021 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 970us/step - loss: 0.0881 - accuracy: 1.0000
# Epoch 43/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 946us/step - loss: 0.0830 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 845us/step - loss: 0.1545 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 898us/step - loss: 0.1620 - accuracy: 0.9787
# Epoch 47/200
# 10/10 [==============================] - 0s 903us/step - loss: 0.2086 - accuracy: 0.9362
# Epoch 48/200
# 10/10 [==============================] - 0s 952us/step - loss: 0.1126 - accuracy: 0.9362
# Epoch 49/200
# 10/10 [==============================] - 0s 876us/step - loss: 0.1147 - accuracy: 0.9787
# Epoch 50/200
# 10/10 [==============================] - 0s 953us/step - loss: 0.1478 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0622 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 778us/step - loss: 0.0548 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 835us/step - loss: 0.0903 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 708us/step - loss: 0.1363 - accuracy: 0.9574
# Epoch 55/200
# 10/10 [==============================] - 0s 961us/step - loss: 0.0813 - accuracy: 1.0000
# Epoch 56/200
# 10/10 [==============================] - 0s 687us/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 57/200
# 10/10 [==============================] - 0s 982us/step - loss: 0.0701 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0603 - accuracy: 0.9787
# Epoch 59/200
# 10/10 [==============================] - 0s 780us/step - loss: 0.0503 - accuracy: 0.9787
# Epoch 60/200
# 10/10 [==============================] - 0s 766us/step - loss: 0.0442 - accuracy: 1.0000
# Epoch 61/200
# 10/10 [==============================] - 0s 986us/step - loss: 0.1052 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 793us/step - loss: 0.0493 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 854us/step - loss: 0.0845 - accuracy: 0.9362
# Epoch 64/200
# 10/10 [==============================] - 0s 922us/step - loss: 0.0571 - accuracy: 0.9787
# Epoch 65/200
# 10/10 [==============================] - 0s 632us/step - loss: 0.1066 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 699us/step - loss: 0.0682 - accuracy: 0.9787
# Epoch 67/200
# 10/10 [==============================] - 0s 644us/step - loss: 0.0601 - accuracy: 1.0000
# Epoch 68/200
# 10/10 [==============================] - 0s 896us/step - loss: 0.0645 - accuracy: 0.9787
# Epoch 69/200
# 10/10 [==============================] - 0s 696us/step - loss: 0.0448 - accuracy: 1.0000
# Epoch 70/200
# 10/10 [==============================] - 0s 673us/step - loss: 0.0468 - accuracy: 1.0000
# Epoch 71/200
# 10/10 [==============================] - 0s 687us/step - loss: 0.0613 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 686us/step - loss: 0.0871 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 687us/step - loss: 0.0578 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 868us/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 615us/step - loss: 0.0498 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 907us/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 714us/step - loss: 0.0752 - accuracy: 1.0000
# Epoch 78/200
# 10/10 [==============================] - 0s 625us/step - loss: 0.0460 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 800us/step - loss: 0.0450 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 597us/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 81/200
# 10/10 [==============================] - 0s 800us/step - loss: 0.0489 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 568us/step - loss: 0.0414 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 937us/step - loss: 0.0470 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 583us/step - loss: 0.0614 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 793us/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 836us/step - loss: 0.0571 - accuracy: 0.9787
# Epoch 87/200
# 10/10 [==============================] - 0s 593us/step - loss: 0.1010 - accuracy: 0.9787
# Epoch 88/200
# 10/10 [==============================] - 0s 639us/step - loss: 0.0618 - accuracy: 1.0000
# Epoch 89/200
# 10/10 [==============================] - 0s 556us/step - loss: 0.0826 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 872us/step - loss: 0.1016 - accuracy: 0.9574
# Epoch 91/200
# 10/10 [==============================] - 0s 627us/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 92/200
# 10/10 [==============================] - 0s 776us/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 675us/step - loss: 0.0992 - accuracy: 0.9787
# Epoch 94/200
# 10/10 [==============================] - 0s 716us/step - loss: 0.0447 - accuracy: 1.0000
# Epoch 95/200
# 10/10 [==============================] - 0s 831us/step - loss: 0.0601 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 605us/step - loss: 0.0252 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 767us/step - loss: 0.0488 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 717us/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 733us/step - loss: 0.0615 - accuracy: 0.9574
# Epoch 100/200
# 10/10 [==============================] - 0s 883us/step - loss: 0.1204 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 602us/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 731us/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 625us/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 104/200
# 10/10 [==============================] - 0s 725us/step - loss: 0.0173 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 564us/step - loss: 0.0131 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 839us/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 614us/step - loss: 0.0424 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 991us/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 750us/step - loss: 0.1075 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 571us/step - loss: 0.0602 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 609us/step - loss: 0.0371 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 753us/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 654us/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 906us/step - loss: 0.0547 - accuracy: 0.9787
# Epoch 115/200
# 10/10 [==============================] - 0s 687us/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 116/200
# 10/10 [==============================] - 0s 647us/step - loss: 0.0481 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 673us/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 839us/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 743us/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 896us/step - loss: 0.0373 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 856us/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 122/200
# 10/10 [==============================] - 0s 640us/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 822us/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 719us/step - loss: 0.0823 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 576us/step - loss: 0.0525 - accuracy: 0.9574
# Epoch 128/200
# 10/10 [==============================] - 0s 643us/step - loss: 0.0321 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 657us/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 701us/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 642us/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 815us/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 968us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 806us/step - loss: 0.0384 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 637us/step - loss: 0.0545 - accuracy: 0.9787
# Epoch 136/200
# 10/10 [==============================] - 0s 797us/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 137/200
# 10/10 [==============================] - 0s 858us/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 754us/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 755us/step - loss: 0.0222 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 740us/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 625us/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 732us/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 896us/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 682us/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 658us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 146/200
# 10/10 [==============================] - 0s 624us/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 611us/step - loss: 0.0395 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 665us/step - loss: 0.0218 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 743us/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 678us/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 631us/step - loss: 0.0166 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 153/200
# 10/10 [==============================] - 0s 626us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 797us/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 723us/step - loss: 0.0503 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 781us/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 157/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 619us/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 801us/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 605us/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 726us/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 869us/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 711us/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 700us/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 748us/step - loss: 0.0390 - accuracy: 0.9787
# Epoch 166/200
# 10/10 [==============================] - 0s 692us/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 724us/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 637us/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 795us/step - loss: 0.0263 - accuracy: 0.9787
# Epoch 170/200
# 10/10 [==============================] - 0s 641us/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 786us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 824us/step - loss: 0.0443 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 655us/step - loss: 0.0329 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 743us/step - loss: 0.0264 - accuracy: 1.0000
# Epoch 175/200
# 10/10 [==============================] - 0s 847us/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 672us/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 644us/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 648us/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 729us/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 180/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 885us/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 771us/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 801us/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 649us/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 585us/step - loss: 0.0763 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 600us/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 646us/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 584us/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 556us/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 835us/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 688us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 555us/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 618us/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 792us/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 695us/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 571us/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 560us/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 596us/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 571us/step - loss: 0.1026 - accuracy: 0.9574
# model is created

# %%
import nltk

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

import pickle

import numpy as np

from keras.models import load_model

model = load_model('chatbot_model.h5')

import json

import random

intents = json.loads(open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/intents.json').read())

words = pickle.load(open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/words.pkl','rb'))

classes = pickle.load(open('/Users/liujiaqi/Downloads/python-project-chatbot-codes/classes.pkl','rb'))

def clean_up_sentence(sentence):

    # tokenize the pattern - splitting words into array

    sentence_words = nltk.word_tokenize(sentence)

    # stemming every word - reducing to base form

    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]

    return sentence_words

# return bag of words array: 0 or 1 for words that exist in sentence

def bag_of_words(sentence, words, show_details=True):

    # tokenizing patterns

    sentence_words = clean_up_sentence(sentence)

    # bag of words - vocabulary matrix

    bag = [0]*len(words)  

    for s in sentence_words:

        for i,word in enumerate(words):

            if word == s: 

                # assign 1 if current word is in the vocabulary position

                bag[i] = 1

                if show_details:

                    print ("found in bag: %s" % word)

    return(np.array(bag))

def predict_class(sentence):

    # filter below  threshold predictions

    p = bag_of_words(sentence, words,show_details=False)

    res = model.predict(np.array([p]))[0]

    ERROR_THRESHOLD = 0.25

    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]

    # sorting strength probability

    results.sort(key=lambda x: x[1], reverse=True)

    return_list = []

    for r in results:

        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})

    return return_list

def getResponse(ints, intents_json):

    tag = ints[0]['intent']

    list_of_intents = intents_json['intents']

    for i in list_of_intents:

        if(i['tag']== tag):

            result = random.choice(i['responses'])

            break

    return result

#Creating tkinter GUI

import tkinter

from tkinter import *

def send():

    msg = EntryBox.get("1.0",'end-1c').strip()

    EntryBox.delete("0.0",END)

    if msg != '':

        ChatBox.config(state=NORMAL)

        ChatBox.insert(END, "You: " + msg + '\n\n')

        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 

        ints = predict_class(msg)

        res = getResponse(ints, intents)

        

        ChatBox.insert(END, "Bot: " + res + '\n\n')           

        ChatBox.config(state=DISABLED)

        ChatBox.yview(END)

root = Tk()

root.title("Chatbot")

root.geometry("400x500")

root.resizable(width=FALSE, height=FALSE)

#Create Chat window

ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatBox.config(state=DISABLED)

#Bind scrollbar to Chat window

scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")

ChatBox['yscrollcommand'] = scrollbar.set

#Create Button to send message

SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,

                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',

                    command= send )

#Create the box to enter message

EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")

#EntryBox.bind("<Return>", send)

#Place all components on the screen

scrollbar.place(x=376,y=6, height=386)

ChatBox.place(x=6,y=6, height=386, width=370)

EntryBox.place(x=128, y=401, height=90, width=265)

SendButton.place(x=6, y=401, height=90)

root.mainloop()
